# %%
import pandas as pd

# %%
reviews = pd.read_csv(r'/Users/satrajitmaitra/Downloads/yelp_dataset/review.csv')

# %%
reviews
# Out:
#          funny  useful               review_id  \
# 0            1       6  Q1sbwvVQXV2734tPgoKj4Q
# 1            0       0  GJXCdrto3ASJOqKeVWPi6Q
# 2            0       3  2TzJjDVDEuAW6MR5Vuc1ug
# 3            0       0  yi0R0Ugj_xUx_Nek0-_Qig
# 4            0       7  11a8sVPMUFtaC7_ABRkmtw
# 5            0       0  fdiNeiN_hoCxCMy2wTRW9g
# 6            4       5  G7XHMxG0bx9oBJNECG4IFg
# 7            1       3  8e9HxxLjjqc9ez5ezzN7iQ
# 8            0       1  qrffudO73zsslZbe8B9D3Q
# 9            0       1  RS_GTIT6836bCaPy637kNQ
# 10           0       0  kbtscdyz6lvrtGjD1quQTg
# 11           1       0  -I5umRTkhw15RqpKMl_o1Q
# 12           0       0  Z7wgXp98wYB57QdRY3HQ3w
# 13           0       0  qlXw1JQ0UodW7qrmVgwCXw
# 14           1       1  JVcjMhlavKKn3UIt9p9OXA
# 15           0       0  svK3nBU7Rk8VfGorlrN52A
# 16           0       0  1wVA2-vQIuW_ClmXkDxqMQ
# 17           7       1  6BnQwlxRn7ZuWdzninM9sQ
# 18           0       0  rEITo90tpyKmEfNDp3Ou3A
# ...

# %%
phoenix_restaurants = pd.read_csv(r"/Users/satrajitmaitra/DV-projects/data/phoenix_restaurants.csv")

# %%
phoenix_restaurants
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  \
# 0              0             1              11
# 1              1             7              78
# 2              2            12             133
# 3              3            15             162
# 4              4            17             181
# 5              5            20             187
# 6              6            29             273
# 7              7            31             276
# 8              8            34             298
# 9              9            35             302
# 10            10            48             409
# 11            11            49             413
# 12            12            52             457
# 13            13            53             468
# 14            14            55             485
# 15            15            57             507
# 16            16            61             523
# 17            17            62             536
# 18            18            71             593
# ...

# %%
df = pd.merge(phoenix_restaurants, reviews, on='business_id', how='inner')

# %%
df
# Out:
#         Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1                     address  \
# 0                0             1              11     2450 E Indian School Rd
# 1                0             1              11     2450 E Indian School Rd
# 2                0             1              11     2450 E Indian School Rd
# 3                0             1              11     2450 E Indian School Rd
# 4                0             1              11     2450 E Indian School Rd
# 5                0             1              11     2450 E Indian School Rd
# 6                0             1              11     2450 E Indian School Rd
# 7                0             1              11     2450 E Indian School Rd
# 8                0             1              11     2450 E Indian School Rd
# 9                0             1              11     2450 E Indian School Rd
# 10               0             1              11     2450 E Indian School Rd
# ...

# %%
df.groupby(['Name','Sid','Revenue'])['Use_Case'].apply(', '.join).reset_index()

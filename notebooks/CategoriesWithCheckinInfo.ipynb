# %%
import pandas as pd

# %%
df1 = pd.read_csv(r"/Users/satrajitmaitra/DV-projects/data/phoenix_restaurants.csv")

# %%
df1
# Out:
#       Unnamed: 0  Unnamed: 0.1  \
# 0              1            11
# 1              7            78
# 2             12           133
# 3             15           162
# 4             17           181
# 5             20           187
# 6             29           273
# 7             31           276
# 8             34           298
# 9             35           302
# 10            48           409
# 11            49           413
# 12            52           457
# 13            53           468
# 14            55           485
# 15            57           507
# 16            61           523
# 17            62           536
# 18            71           593
# 19            73           601
# 20            74           610
# 21            76           635
# 22            81           655
# 23            86           673
# 24            87           681
# 25            90           708
# 26            92           733
# 27           101           809
# 28           102           811
# ...

# %%
df2 = pd.read_csv(r"/Users/satrajitmaitra/DV-projects/data/checkin.csv")

# %%
df3 = pd.merge(df1, df2, on='business_id', how='inner')

# %%
df3.to_csv("/Users/satrajitmaitra/DV-projects/data/phoenix_restaurants.csv")

# %%
df3
# Out:
#       Unnamed: 0  Unnamed: 0.1  \
# 0              1            11
# 1              7            78
# 2             12           133
# 3             15           162
# 4             17           181
# 5             20           187
# 6             29           273
# 7             31           276
# 8             34           298
# 9             35           302
# 10            48           409
# 11            49           413
# 12            52           457
# 13            53           468
# 14            55           485
# 15            57           507
# 16            61           523
# 17            62           536
# 18            71           593
# 19            73           601
# 20            74           610
# 21            76           635
# 22            81           655
# 23            86           673
# 24            87           681
# 25            90           708
# 26            92           733
# 27           101           809
# 28           102           811
# ...

# %%
df4 = df3[df3.categories.str.contains("Burgers")]

# %%
df4
# Out:
#       Unnamed: 0  Unnamed: 0.1  \
# 8             34           298
# 19            73           601
# 43           157          1341
# 52           206          1737
# 56           216          1806
# 80           309          2559
# 82           317          2612
# 91           361          2995
# 94           369          3043
# 96           382          3194
# 97           385          3215
# 117          466          3817
# 122          474          3865
# 130          495          4038
# 141          552          4513
# 142          555          4523
# 145          569          4631
# 147          571          4637
# 152          579          4725
# 155          593          4820
# 164          633          5082
# 165          634          5092
# 176          677          5401
# 205          795          6264
# 212          813          6361
# 229          867          6775
# 268         1008          7793
# 269         1010          7803
# 271         1019          7873
# ...

# %%
df4.to_csv("/Users/satrajitmaitra/DV-projects/data/phoenix_burger_restaurants.csv")
